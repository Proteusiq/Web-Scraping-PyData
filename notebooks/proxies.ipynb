# %%
import pandas as pd
import requests

r = requests.get('https://sslproxies.org/')
proxies_df = pd.read_html(r.text, attrs={'id':'proxylisttable'}, flavor='lxml', skiprows=[101])[0]
proxies_df
# Out:
#         IP Address   Port Code    Country    Anonymity Google Https  \
# 0    51.159.24.172   3162   FR     France  elite proxy     no   yes
# 1   194.44.172.254  23500   UA    Ukraine    anonymous     no   yes
# 2   116.90.229.186  35561   NP      Nepal    anonymous     no   yes
# 3     91.192.2.168  53281   PL     Poland    anonymous     no   yes
# 4   118.172.211.11  56143   TH   Thailand    anonymous     no   yes
# ..             ...    ...  ...        ...          ...    ...   ...
# 95  187.243.240.54   8080   MX     Mexico  elite proxy     no   yes
# 96  103.210.120.40  34018   ID  Indonesia  elite proxy     no   yes
# 97   135.181.68.88   3128   DE    Germany  elite proxy     no   yes
# 98  110.36.232.242  49850   PK   Pakistan  elite proxy     no   yes
# 99  13.250.105.206   8888   SG  Singapore    anonymous     no   yes
#
#              Last Checked
# 0           3 seconds ago
# 1           2 minutes ago
# 2           2 minutes ago
# 3           2 minutes ago
# 4           2 minutes ago
# ..                    ...
# 95  1 hour 23 minutes ago
# 96  1 hour 23 minutes ago
# 97  1 hour 23 minutes ago
# 98  1 hour 23 minutes ago
# 99  1 hour 23 minutes ago
#
# [100 rows x 8 columns]

# %%
index = 0
print(proxies_df.loc[index,])

print('\nProxy selected:')
print(f"\t{proxies_df.loc[index,'IP Address']}:{proxies_df.loc[index, 'Port']}")
# Out:
# IP Address      51.159.24.172
# Port                     3162
# Code                       FR
# Country                France
# Anonymity         elite proxy
# Google                     no
# Https                     yes
# Last Checked    3 seconds ago
# Name: 0, dtype: object
#
# Proxy selected:
# 	51.159.24.172:3162

# %%
PROXY = f"{proxies_df.loc[index,'IP Address']}:{int(proxies_df.loc[index, 'Port'])}"
    
proxies = {
 # 'http': f'http://{PROXY}',
  'https': f'http://{PROXY}',
}

r = requests.get("https://www.myip.com/", proxies=proxies)

start = r.text.find('id="ip"') + 8
end = start + r.text[start:].find('<')
r.text[start:end]
# Out:
# '45.74.18.226'

# %%
# elite proxy works
