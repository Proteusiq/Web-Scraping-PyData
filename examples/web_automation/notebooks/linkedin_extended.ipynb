# %%
# %run ./run_before_notes.py
# Out:
# Notebooks Import Ready

# %%
import json
import re
import os

# %%
import numpy as np
import pandas as pd

# %%
from bs4 import BeautifulSoup
from selenium.common import exceptions

# %%
from linkedin_selenium import LinkedIn
from utils.helpers import driver_tags

# %%
user = os.environ.get('LINKEDIN_USER')
pwd = os.environ.get('LINKEDIN_PWD')
    
linkedin = LinkedIn(snooze=1)
# Out:
# 25-Jul-19 12:05:10 [INFO] Setting Up LinkedIn

# %%
linkedin.sign_in(username=user,password=pwd)
# Out:
# 25-Jul-19 12:05:11 [INFO] Login in LinkedIn
# 25-Jul-19 12:05:18 [INFO] Login Successful
# [On] LinkedIn('Prayson Wilfred Daniel')

# %%
# Added to utils
# def driver_tags(driver, search, query, parser='lxml'):
    
#     soup = BeautifulSoup(driver.page_source, parser)
    
#     methods = {
#         'find_all': soup.find_all,
#         'find': soup.find,
#     }
    
#     return methods[search](query)

# %%
pattern = re.compile('^bpr-guid-*')
codes = driver_tags(linkedin.driver, search='find_all',query=('code',{'id':pattern}))

# %%
data = [code.get_text(strip=True) for code in codes if 'publicContactInfo' in code.get_text(strip=True)] # metatadata

# %%
mig = json.loads(data[-1])

# %%
f"{mig['included'][0]['firstName']} {mig['included'][0]['lastName']}"
# Out:
# 'Prayson Wilfred Daniel'

# %%
mig['included'][0]['lastName']
# Out:
# 'Daniel'

# %%
# soup = driver_soup(linkedin.driver)

# pattern = re.compile('^bpr-guid-*')
# codes = soup.find_all('code',{'id':pattern})

# data = [code.get_text(strip=True) for code in codes if 'metadata' in code.get_text(strip=True)]
# # json.loads(data[-1])

# %%
ROOT_URL = 'https://www.linkedin.com'

# %%
df = pd.read_pickle('../linkedin.pkl')

# %%
profile_index = np.random.randint(low=1, high=df.shape[0], size=1)[0]
profile = df.iloc[profile_index]

# %%
print(profile['profile_name'])
profile_url = f"{ROOT_URL}{profile['profile_url']}"
# Out:
# Kasper Bang Hede Kramhøft

# %%
linkedin.driver.get(profile_url)

# %%
# has_about = True
# try:
#     linkedin.driver.find_element_by_class_name('lt-line-clamp__more').click()
# except (exceptions.ElementNotInteractableException,
#         exceptions.NoSuchElementException):
#     print('No Abouts')
#     has_about = False
    
# except exceptions.ElementClickInterceptedException:
#     linkedin.driver.find_element_by_class_name('msg-overlay-bubble-header').click()
#     linkedin.driver.find_element_by_class_name('lt-line-clamp__more').click()
    
# finally:
#     source = linkedin.driver.page_source

# %%
soup = BeautifulSoup(linkedin.driver.page_source,'lxml')

# %%
soup.find('a',{'data-control-name':'topcard_view_all_connections'})
# Out:
# <a class="ember-view" data-control-name="topcard_view_all_connections" href="/search/results/people/?facetConnectionOf=%5B%22ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU%22%5D&amp;facetNetwork=%5B%22F%22%2C%22S%22%5D&amp;origin=MEMBER_PROFILE_CANNED_SEARCH" id="ember97"> <span class="t-16 t-bold">
#                     500+ connections
#                   </span>
# </a>

# %%
next_connections = soup.find('a',{'data-control-name':'topcard_view_all_connections'})

# %%
connections_count = next_connections.get_text(strip=True).split()[0]

# %%
next_connections['href']
# Out:
# '/search/results/people/?facetConnectionOf=%5B%22ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU%22%5D&facetNetwork=%5B%22F%22%2C%22S%22%5D&origin=MEMBER_PROFILE_CANNED_SEARCH'

# %%
next_url = f"{ROOT_URL}{next_connections['href']}"
linkedin.driver.get(next_url)

# %%
linkedin.driver.find_elements_by_class_name("search-s-facet__form")[0].click()

linkedin.driver.find_element_by_class_name("facet-collection-list__clear-button").click()

linkedin.driver.find_element_by_class_name("facet-collection-list__apply-button").click()

# %%
linkedin.driver.current_url
# Out:
# 'https://www.linkedin.com/search/results/people/?facetConnectionOf=%5B%22ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU%22%5D&facetNetwork=%5B%22F%22%2C%22S%22%5D&origin=MEMBER_PROFILE_CANNED_SEARCH'

# %%
linkedin.driver.get(linkedin.driver.current_url)

# %%
soup = BeautifulSoup(linkedin.driver.page_source,'lxml')
pattern = re.compile('^bpr-guid-*')
codes = soup.find_all('code',{'id':pattern})

data = [code.get_text(strip=True) for code in codes if 'metadata' in code.get_text(strip=True)]
# json.loads(data[-1])

# %%
d = json.loads(data[-1])

# %%
d
# Out:
# {'data': {'metadata': {'searchId': 'f903ae57-acfb-4955-9654-e8ac540a8570',
#    'totalResultCount': 559,
#    'origin': 'MEMBER_PROFILE_CANNED_SEARCH',
#    'numVisibleResults': 10,
#    '$type': 'com.linkedin.voyager.search.BlendedSearchMetadata'},
#   'entityUrn': 'urn:li:collectionResponse:yirYVhIbf6uNytf5E/Akykn3g/eNQeuSWY1pQHSJeQs=',
#   'elements': [{'extendedElements': [{'searchTieIn': 'FREE_UPSELL',
#       'type': 'SEARCH_TIE_IN',
#       '$type': 'com.linkedin.voyager.search.ExtendedSearchHit'}],
#     'elements': [],
#     'type': 'SEARCH_FEATURES',
#     '$type': 'com.linkedin.voyager.search.BlendedSearchCluster'},
#    {'extendedElements': [],
#     'elements': [{'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAtCrwQBnBssAIDRdgzpu367wTZ472uXsk8',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAwOO7oByiG5VfALPzaDc-zZTULxs4P216U',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:666494856',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Sofie Toft Svendsen',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '12 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I',
#       'publicIdentifier': 'sofie-toft-svendsen-06025b167',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Skadesbehandler hos If Insurance (If P&C Insurance)',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'mTbUpE+aTs60ODLhRQH0cw=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAA5mXbEBzL0x1t8gK8r-LIq7L58tsKRbQsY',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAA7-luUBgXqUvoGxkewe7lB4wNUUfSo8qzo',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:506755071',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Amanda Liv Lerche Hyrdum',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '3 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI',
#       'publicIdentifier': 'amanda-liv-lerche-hyrdum-053865121',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Bankrådgiver, Trainee hos Jyske Bank',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'k3onKoPIQcS7D6rMW7uJ4Q=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB3XBMBs6aTuvafCmp4ilF2GPb9DHxLdSg',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAG8oVABRClPuA57avz4LzVjCAzBAT4PgzE',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:283391638',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Kevin Willendrup',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '22 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A',
#       'publicIdentifier': 'kevin-willendrup-95aaa77a',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Uddannelsesansvarlig hos If P&C Insurance',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'w4Z7AUrQTQ6mUJKAJYQaQQ=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAKrBuEBU0-iNeP6c5lg3Cr9t8NLGoqxmA8',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAALKA9ABwM1kNTrZ2iVD1qiYvKYB1tort9A',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:523712161',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Louise Stecher-Hansen',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '9 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A',
#       'publicIdentifier': 'louise-stecher-hansen',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': '...',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'GvpuivmwTquPntU0MhW0rQ=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADKNycBfqpQq1j6bCdtRq92h-cID9vCN24',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADx1BMBJTvmXvYDpS2t6woIlH4Rj-2RSpY',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:663565694',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Nikolaj Ancher',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '34 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4',
#       'publicIdentifier': 'nikolaj-ancher-b12287166',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Senior konsulent FRIDA forsikring',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'JBK/f7ewT5ef5d0PY1oVDA=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:426432364',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Laura Knudsen',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '4 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U',
#       'publicIdentifier': 'laura-knudsen-ba4989ba',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Junior Underwriter',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': '4l0FVXjsR1iAtYe9oBjJMA=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAACuHQBhodDjj8c25cbcyTbwcG6fFr-BFw',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABHwmwBi5VEdkXs9vznBi6MWuEi-lrCjnI',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB0cBMBt4y8SJDCXGtmdmad3gWuWBkMMVY',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:390773988',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Thomas k. Deloncé',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '37 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E',
#       'publicIdentifier': 'thomas-k-deloncé-430a52aa',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Insurance Consultant at Alka Forsikring',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'uO3HLei7RpGnl48lyTtaZQ=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAAKjeYBY96-3kS7ttenaC-K5iaP41NGz2w',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB3XBMBs6aTuvafCmp4ilF2GPb9DHxLdSg',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:455388990',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Nikolaj Lehrmann Thygesen',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '11 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ',
#       'publicIdentifier': 'nikolaj-lehrmann-thygesen-366613108',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Erhvervsrådgiver hos If P&C Insurance',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'Kb4nebBGQeuNSGqds7UfHg=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABUdCYB74ivapFO4Ljdb5p1fJO0_CRiQM0',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABvG1oBQTJYxGsJWWYeqrDW-sWMJxkqYIM',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:324776978',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Lars Hyldig',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '46 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ',
#       'publicIdentifier': 'lars-hyldig-78292590',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Development Consultant hos If Insurance (If P&C Insurance)',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'GUqhy4FMSIOLAd15+XgILg=='},
#      {'memberDistance': {'value': 'DISTANCE_2',
#        '$type': 'com.linkedin.voyager.common.MemberDistance'},
#       'image': {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#          '*miniProfile': 'urn:li:fs_miniProfile:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos',
#          '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#        'accessibilityTextAttributes': [],
#        '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#       'targetUrn': 'urn:li:fs_miniProfile:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos',
#       'socialProofImagePile': [{'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAACLgcBTLNHefMylgfe1EJpAiWKk-3aSt0',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABHwmwBi5VEdkXs9vznBi6MWuEi-lrCjnI',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'},
#        {'attributes': [{'sourceType': 'PROFILE_PICTURE',
#           '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c',
#           '$type': 'com.linkedin.voyager.common.ImageAttribute'}],
#         'accessibilityTextAttributes': [],
#         '$type': 'com.linkedin.voyager.common.ImageViewModel'}],
#       'trackingUrn': 'urn:li:member:280739975',
#       'title': {'textDirection': 'FIRST_STRONG',
#        'text': 'Kate Hedebroe',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'type': 'PROFILE',
#       '$type': 'com.linkedin.voyager.search.SearchHitV2',
#       'headless': False,
#       'socialProofText': '65 shared connections',
#       'secondaryTitle': {'textDirection': 'USER_LOCALE',
#        'text': '2nd',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       '*badges': 'urn:li:fs_memberBadges:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos',
#       'publicIdentifier': 'kate-hedebroe-31b0297a',
#       'headline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Uddannelse hos If P&C Insurance',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'nameMatch': False,
#       'subline': {'textDirection': 'FIRST_STRONG',
#        'text': 'Copenhagen Area, Capital Region, Denmark',
#        '$type': 'com.linkedin.voyager.common.TextViewModel'},
#       'trackingId': 'YlkzV2dtQyGfuSvQMZvwIw=='}],
#     'type': 'SEARCH_HITS',
#     '$type': 'com.linkedin.voyager.search.BlendedSearchCluster'}],
#   'paging': {'total': 559, 'count': 10, 'start': 0, 'links': []},
#   '$type': 'com.linkedin.restli.common.CollectionResponse'},
#  'included': [{'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'premium': False,
#    'influencer': False,
#    'entityUrn': 'urn:li:fs_memberBadges:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ',
#    'openLink': False,
#    'jobSeeker': False,
#    '$type': 'com.linkedin.voyager.identity.profile.MemberBadges'},
#   {'firstName': 'Mathias Hollhut',
#    'lastName': 'Hansen',
#    'occupation': 'Fagansvarlig forsikringsrådgiver',
#    'objectUrn': 'urn:li:member:188919556',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAtCrwQBnBssAIDRdgzpu367wTZ472uXsk8',
#    'backgroundImage': None,
#    'publicIdentifier': 'hollhut',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=iXVewLClCkxSo58jYNOCI0wQqlhm8xegOmnn_4IovQA',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=Cg7mLod5PE1Sw2XXr9r2B77YozFCGcCLNDwKjRQ4HFU',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=wd-KtKQKbeQumI8wC_-PSzNoO-GU_iU1QqsYOiUoEE8',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=kWJ11sIsBXZFSCNsR94EQyhnKVLQZ9huAGRFGSjicek',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQGbc_67wnNztQ/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'gBvQgZvCS0mGQgyJwGeI+g==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Peter',
#    'lastName': 'Hviid Schack',
#    'occupation': 'Business & Financial Controller, BA Private, If Denmark',
#    'objectUrn': 'urn:li:member:142855',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAACLgcBTLNHefMylgfe1EJpAiWKk-3aSt0',
#    'backgroundImage': None,
#    'publicIdentifier': 'peter-hviid-schack-8076a',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=pPUH_m7IAVIBg8j23hlsCE50kVGHX8TfkLbmh1UtLFg',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=c66fhesOWZ_0cKIkO4f4pKJaD2aBp0cbIICPsQzaopA',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=GN3NynEfZzUj__1ruVpow6eUGesaNrdSCKQSEtp3xvQ',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=5e4oDVV3mU6b8cxYloZdEOa7STI9PhdRXu_smh6N13Y',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQEMynAJzsxbEw/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': '0OjZJvowRymwgcivqv5mQg==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Peter',
#    'lastName': 'Linde',
#    'occupation': 'Sales Manager',
#    'objectUrn': 'urn:li:member:13252391',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAADKNycBfqpQq1j6bCdtRq92h-cID9vCN24',
#    'backgroundImage': None,
#    'publicIdentifier': 'peterlinde',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=_fDuMW1ZyU7tixPJefLuEXt5YI6_BWIyGN8owJZudso',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=8xBBCa6I7TH7pP0deBHEJabZyfLjBpztMxdOsIE2XgY',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=NDluIuvJNd9j_b7LBOVotTfvKIn2mVZ79M3YynQoaEE',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=ggn8ev7YycTYF6nJv6l3yxRMufw6KUt4TbMgU9oqJXg',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQHamjQSIXfcXg/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'Ey0bd8rlTUKJ4h7x2mBP0w==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Thomas',
#    'lastName': 'k. Deloncé',
#    'occupation': 'Insurance Consultant at Alka Forsikring',
#    'objectUrn': 'urn:li:member:390773988',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E',
#    'backgroundImage': None,
#    'publicIdentifier': 'thomas-k-deloncé-430a52aa',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=raCt53UorsP4qVhLkDyCPecwj26UG13rqeoHTv16RBs',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=6Yxghbvi1HKCMpHS1MxAu_vUxL53YLqwvMAC5x_v90c',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=Z_BS4AvHcCGA5tNkCfjbRVPnJW3OztLUwJ3mzzSsmZg',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=kkdPeLDrdfQKbU-Qc3opmJ51Nli7E-mUhfb1VKDT99Q',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQHmivxWTPaRNw/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'J0Vl6RhrTmGElx67IZAg/A==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Betina',
#    'lastName': 'Nygaard',
#    'occupation': 'Head of System/UW Denmark',
#    'objectUrn': 'urn:li:member:15848467',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAADx1BMBJTvmXvYDpS2t6woIlH4Rj-2RSpY',
#    'backgroundImage': None,
#    'publicIdentifier': 'betina-nygaard-6973835',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=PpwsRoovNSuZPXTIi_OrsGls3o7lqqtjWizqcgvUtpU',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=YqdOFvDNbWfppRT_2HrLCwWlmaT7u98HiekXGSodv-k',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=S68nIgKv522asA-X51jwrREESopGuR2xkdOs_5sezpE',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=-DWhtkS1gdLJeIsnRGkxz6az1_N_B4z56mBWIiFp3dc',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQHPP7MtCCdEDA/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'psCWbv2xTBuxLOEoeG8q5g==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Laura',
#    'lastName': 'Knudsen',
#    'occupation': 'Junior Underwriter',
#    'objectUrn': 'urn:li:member:426432364',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U',
#    'backgroundImage': None,
#    'publicIdentifier': 'laura-knudsen-ba4989ba',
#    'picture': None,
#    'trackingId': 'EsoxvkvsTi6zDU1YhoFkZw==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Betina',
#    'lastName': 'Scheye Maibom',
#    'occupation': 'HR Business Partner - If P&C Insurance',
#    'objectUrn': 'urn:li:member:12611777',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk',
#    'backgroundImage': None,
#    'publicIdentifier': 'betina-scheye-maibom-5952824',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=R9zV250Fb_XimNdiM-eBRxbUZyKs9slLHuymOqhofqM',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=3hbpNUtUnMm-ju915IMsXfPBa1cytJ0fkEnumWYfqy8',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=rogOF4EYrKdg_EViXVPiSBziaGtBHx6FkzpluRoDqjc',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=GPyoGATKvIJmPQIw2EE1jr03DCuCIDTE3imb6OTaHX8',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQHZClbehrfXiQ/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': '1s1VAKTXSnyJ0sIBn6bfKQ==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Nikolaj Lehrmann',
#    'lastName': 'Thygesen',
#    'occupation': 'Erhvervsrådgiver hos If P&C Insurance',
#    'objectUrn': 'urn:li:member:455388990',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ',
#    'backgroundImage': None,
#    'publicIdentifier': 'nikolaj-lehrmann-thygesen-366613108',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=fQzaULwgDCVmvh-BjGyLoANiGUtl1yrWZZx5rT3DH9E',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=K9nNGK43KeVEe7j77i8Gihi52hhUdPw4OrhksFf3KPU',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=944MeXv5RjftLrQ-KvTPtQR0FDdnzPMajHlepWSI42Q',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=pXrw0O8UfYq-YnyRaVsf29-xpWgMjbnCW4rsufEpK_o',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQHJ2moUtUVsAg/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'ofCBDrZsQBmHpkd3AP0dkg==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Morten',
#    'lastName': 'Nielsen',
#    'occupation': 'Forsikring',
#    'objectUrn': 'urn:li:member:110665920',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0',
#    'backgroundImage': None,
#    'publicIdentifier': 'morten-nielsen-94008a31',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=7R_eyeD5SsenR_7X45S-jBkW4QGLOcILoAXmFz_z8VE',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=-JOd3NheGrpGmUOt6HyozmUjEsZ0LMgSMkI-oaAQ_tI',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=7CB6WeuV3KqBDDF1rcnyGy53Cajmdxy3xWg9vVTPlV0',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=ht85r4-2uti2qDgK7x7ZUSA37wWw0ZP8BooIlk48zjU',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQGO4k6MTdltHg/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'bSNDSyJ/RJa+5yR/nn/gRg==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Diana',
#    'lastName': 'Lundin Mühlerwirth',
#    'occupation': 'Marketing Projektleder - marketingkonsulent - koordinator- digital markedsføring - SoMe - CRM - bureau samarbejder',
#    'objectUrn': 'urn:li:member:7281498',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAABvG1oBQTJYxGsJWWYeqrDW-sWMJxkqYIM',
#    'backgroundImage': None,
#    'publicIdentifier': 'diana-lundin-mühlerwirth-9b65312',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=Tq07nY_A0xSqcS8ncneIpctfFVNkrwNUakwBdTm2aJo',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=9xycwXuWAVMcTd86QCcBj9a3RU4OiQkSxLBkzmZohaQ',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=7Dwh4dFDiuhtP_NiV9ldByV9aSeVREVYw8Ltf_ImW84',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=xaegSeMqmayYh7AyfcH0Tw8ypa7fqLw6HbILn1ukyXs',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQEZFfmJQ5E7QA/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'L7HSoTnMT9K4J0lvxfEdnA==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Kasper Bang Hede',
#    'lastName': 'Kramhøft',
#    'occupation': 'Forsikringsrådgiver hos Gjensidige',
#    'objectUrn': 'urn:li:member:453070511',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU',
#    'backgroundImage': None,
#    'publicIdentifier': 'kasper-bang-hede-kramhøft-6bb895107',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=joeYN0r8U-5J7XZ9V1vsWPid6sxLw4-mHIKpx414UXM',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=Xp-Koz0Pgvdt8WAPalrJ0quprvw-I_fH0wtCI8Cxcx8',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=Vq0m0PH0TCiPvW56BB-8xHiiqZ079jzCyvYPyTwi0l0',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=ttVp5ZoWai373M5qVqkQxAsvtpZtfA8FDac9nvp2X0I',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQGo-q9zJNf2AQ/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'R29inMTaR5edvzOT+M6iIA==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Preben Sander',
#    'lastName': 'Danielsen',
#    'occupation': 'Head of Investigation Unit at If P&C Insurance',
#    'objectUrn': 'urn:li:member:46793680',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAALKA9ABwM1kNTrZ2iVD1qiYvKYB1tort9A',
#    'backgroundImage': None,
#    'publicIdentifier': 'preben-sander-danielsen-81480713',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=eTdvg0AFD5uPFtTkuorVvX5E6JMSwtwQ_bauWU8rNA8',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=xGTCJRfCGQEH1xpMyyH0xWL-sAtzL3MEF2aQChVYpbI',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=37trT7RCFVNKIzYFDA3uRmNgg3MMft2PhOfWkPefEJQ',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=lQTcwUQ3REWBG1wMd6_nrENX5lB2q4P7iGQzsGv_yWU',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4D03AQHcslhzC-sDWw/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'KzQj/kwmQKmDglE7IbxZyQ==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Thomas Sahl',
#    'lastName': 'Grøndahl',
#    'occupation': 'Head of Risk Selection Pers. Insurance | Leadership | Business Development | Digital Development | Customer Experience',
#    'objectUrn': 'urn:li:member:6922901',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c',
#    'backgroundImage': None,
#    'publicIdentifier': 'thomas-sahl-grøndahl-38539a2',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=rrZnCAqasSCqQkGnl3Exg2p1f7usmn1fYM30jd7mqYc',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=Px-T20GXLV_Cu63xr1nEHWWkajUN5UKkDpDW84x2TZA',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=HFT3btP_fntc91-HYcJyAQzT5Js8ag5EzGRICqQPT0E',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
# ...
#    'objectUrn': 'urn:li:member:691686',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAAKjeYBY96-3kS7ttenaC-K5iaP41NGz2w',
#    'backgroundImage': None,
#    'publicIdentifier': 'jussikoski',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=UXzu8dOj56CXrKUmOy90NOGBeUj0ZJcoAZtG_GY9Xjc',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=krb31UsRHjzF74t2CbIRU3vGM0MsDQHWENNSaASdGgY',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=hXg7SGk7UVSyPDzvaLdzE65A-QerupLdYMsjdHKOck4',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=9xWXimG0_aJBLb2Kkk3U-gBfW0DOK3LC3T03sorZCDo',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQEDtDihxrCYEg/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': '6gaNL2FyR9OklR5VXuVV4w==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Asger',
#    'lastName': 'Fløche Møller',
#    'occupation': 'Assurandør og Produktchef, If Forsikringscenter Roskilde',
#    'objectUrn': 'urn:li:member:241589681',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAA5mXbEBzL0x1t8gK8r-LIq7L58tsKRbQsY',
#    'backgroundImage': {'artifacts': [{'width': 800,
#       'fileIdentifyingUrlPathSegment': '200_800/0?e=1569456000&v=beta&t=Z3A96MfvNgCezjYbEwrqXTTUGXoDDtS6yvMqpy7zZI0',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 1400,
#       'fileIdentifyingUrlPathSegment': '350_1400/0?e=1569456000&v=beta&t=d3OGjw_5SmrKjxNn7AskwK-PX8epu_LX_iNzO2RwiEs',
#       'expiresAt': 1569456000000,
#       'height': 350,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E16AQGSnay337txEw/profile-displaybackgroundimage-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'publicIdentifier': 'asger-fløche-møller-a15aa868',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=7XLAb9UKhGTIWZGp4I1R_Vhex8T5FMO--dgbrAL43ws',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=J7vjGnDms3WMuurjDRsY2xuu-s8ot78eJAktcxYU_pY',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=7VvFzyquhejkdz0HM0JfrhRBoNIbOXVkh-A8Jhqxmas',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=MeQ1nk3q9o1pC20wdBbaxwm-MAfJxsUJAvSDB61AMIA',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQEnwXmK0g41dQ/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'jcG9kgrSRce2ETCAoIBDlQ==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Michael',
#    'lastName': 'Holst',
#    'occupation': 'Outgoing and creative personality ALWAYS in search of new challenges :)',
#    'objectUrn': 'urn:li:member:29139280',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAG8oVABRClPuA57avz4LzVjCAzBAT4PgzE',
#    'backgroundImage': None,
#    'publicIdentifier': 'holstfoto',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=cma-PHks2D5HId6WrzuvJ9KfLtWOLkrFfUsO9HAyr2w',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=WaPHo-h1jo6n6FDJjOr82jfGYu1fqpjym01HIToaJYo',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=9fKziFNnNiPSylUaWj5brlndxkB8jKRWRUF9ma-aEs4',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=nNsFYsx7TXVFh-2ARw_sewrU1LZUAk4oEcbtN75Tkfc',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5603AQEUXI22s9oe2g/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'UJCDvlmgSj+gVYyWM3ImQw==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Nikolaj',
#    'lastName': 'Ancher',
#    'occupation': 'Senior konsulent FRIDA forsikring',
#    'objectUrn': 'urn:li:member:663565694',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4',
#    'backgroundImage': None,
#    'publicIdentifier': 'nikolaj-ancher-b12287166',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=ZOzOQo8qCIRkoxF9fnV1Im2foSnRO_UecwaOznwtERI',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=WOYYeP3OAeRBwdEdiIoWKiZT52-bVcC1wJx-jr3uaNA',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=R8Zgu5c3nARhHHw86Vs1fcnpjB-2avaCrPCD5_5tXWs',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=L57Wm7L2nKGER1UBJJdoTEenPb3yFXVLKToqN5RwuLE',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQFgXhkMp530fA/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'VkjXn4TrSM+R8aR6cUfkkw==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Sofie Toft',
#    'lastName': 'Svendsen',
#    'occupation': 'Skadesbehandler hos If Insurance (If P&C Insurance)',
#    'objectUrn': 'urn:li:member:666494856',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I',
#    'backgroundImage': None,
#    'publicIdentifier': 'sofie-toft-svendsen-06025b167',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=Cr5KEE6QLFUwF-dP8Edmv2CQBHf8ZMuRJakfE3VVsZc',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=tyBr_paC43GzcKvXGU4qIiGswV4THm67GIKvnv7xbCg',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=QZjhPcHStU-7LtQbfQIP1BEDc0tefhASaceZ7XYsZIk',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=4Zk12wiKldUj6CZzPf-zDeLVI9Jw2fyuHc_mFfTFDio',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4D03AQGC815qnenQpA/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'SghTSM4XRdC//Xq9gWhwtA==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Lars',
#    'lastName': 'Thrane-Møller',
#    'occupation': 'Headhunter and CEO LTM Search 30.000 + connections',
#    'objectUrn': 'urn:li:member:178292',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAACuHQBhodDjj8c25cbcyTbwcG6fFr-BFw',
#    'backgroundImage': None,
#    'publicIdentifier': 'thrane',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=WCFqyxYYOWf2OibcxwC2-IoSFF6MzUlm2vnNC88Qx-A',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=j5RmjsceRUkUe0bwTibrWeAIy5DzIIUc9kztyeM3OHs',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=2DLUM6zJWCXxqFz98ez8VZSK9VauhqPjUdTXrQDp5sU',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=fKCCnQEOgcJ8Z23oI7169bik5ds12pKglZmES18B6Lw',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQFxGgzN59sw_Q/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'ZDkBaeRdT7OH8Ju4SEnT9Q==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Kate',
#    'lastName': 'Hedebroe',
#    'occupation': 'Uddannelse hos If P&C Insurance',
#    'objectUrn': 'urn:li:member:280739975',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos',
#    'backgroundImage': None,
#    'publicIdentifier': 'kate-hedebroe-31b0297a',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=EzRYA5io9gSFoke2FxB0dchAXitNInPBtWJMSp5ReQs',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=o5aIoudIvxnW4LHD8yFqz6o5MEM5V2r3pgZUyi4ydEI',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=dSFvbVATkJ94y8jYu-6rYduMZceN8_BxCJdYBOKT4Ts',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=bv4tDQ_r5siBgSGzh59H8ZSHIUuM3Q124lGtZhXqpMs',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4E03AQHIUh17qYSClw/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'l7CIM/75TN+JbjlBUWgTIA==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Amanda',
#    'lastName': 'Liv Lerche Hyrdum',
#    'occupation': 'Bankrådgiver, Trainee hos Jyske Bank',
#    'objectUrn': 'urn:li:member:506755071',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI',
#    'backgroundImage': None,
#    'publicIdentifier': 'amanda-liv-lerche-hyrdum-053865121',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=CkfT8CLe9sim_W-i7nzK4flyfJPIjkhEPSMrvxmlSDw',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=kGL4dGyFwieilpy7FuG-7wvyeoY6EueryB18cD_4AyY',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=FZWcM42ITYwYKjmHN-2QO5qe-695ls3JFdVZ28vcPpg',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=30qHdRbSibimsZ0tx54YzC39BRsS4MWGSCxSleygxF0',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4D03AQFnLRLRWkMuXA/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': '9dbQoTs0REqBmPzx4mNtlw==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Kevin',
#    'lastName': 'Willendrup',
#    'occupation': 'Uddannelsesansvarlig hos If P&C Insurance',
#    'objectUrn': 'urn:li:member:283391638',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A',
#    'backgroundImage': None,
#    'publicIdentifier': 'kevin-willendrup-95aaa77a',
#    'picture': None,
#    'trackingId': 'KNMPZiztQkudZZ8Yq8TJ0Q==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'},
#   {'firstName': 'Rikke',
#    'lastName': 'Thomsen',
#    'occupation': 'Head of Marketing & Digital, Nordics',
#    'objectUrn': 'urn:li:member:7630867',
#    'entityUrn': 'urn:li:fs_miniProfile:ACoAAAB0cBMBt4y8SJDCXGtmdmad3gWuWBkMMVY',
#    'backgroundImage': {'artifacts': [{'width': 800,
#       'fileIdentifyingUrlPathSegment': '200_800/0?e=1569456000&v=beta&t=RPN3jKpYq5Fy3DNkHnV2Jq-X5l6gHJDHUwbVdvWluwE',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 1400,
#       'fileIdentifyingUrlPathSegment': '350_1400/0?e=1569456000&v=beta&t=GTKT2tqHrLiNVjAxnHmwPLef_rPKU0YnrPXsamerCds',
#       'expiresAt': 1569456000000,
#       'height': 350,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C5616AQFp4q2g7zpwbA/profile-displaybackgroundimage-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'publicIdentifier': 'rikkethomsen',
#    'picture': {'artifacts': [{'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0?e=1569456000&v=beta&t=C1Hw7Y84vfLFsVAzHu7yIQFo-u5zzMQF-_r_0pxdrk8',
#       'expiresAt': 1569456000000,
#       'height': 100,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0?e=1569456000&v=beta&t=P-QN1S_caX7wgnBgyxfhaAXO7v57irAMb_NBVzKHHtA',
#       'expiresAt': 1569456000000,
#       'height': 200,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0?e=1569456000&v=beta&t=RAh2-xJbwJTTBzm3OAS5Apr9bo0y9MsKuVfsD5MEDIY',
#       'expiresAt': 1569456000000,
#       'height': 400,
#       '$type': 'com.linkedin.common.VectorArtifact'},
#      {'width': 800,
#       'fileIdentifyingUrlPathSegment': '800_800/0?e=1569456000&v=beta&t=8jxKDg8U4JQ6OzQw8IMVeaXfVmf1CDWI98PvFOW1XhM',
#       'expiresAt': 1569456000000,
#       'height': 800,
#       '$type': 'com.linkedin.common.VectorArtifact'}],
#     'rootUrl': 'https://media.licdn.com/dms/image/C4D03AQEcrUY3Dz5nrg/profile-displayphoto-shrink_',
#     '$type': 'com.linkedin.common.VectorImage'},
#    'trackingId': 'QG9pfU67R0iGaMP10hqAww==',
#    '$type': 'com.linkedin.voyager.identity.shared.MiniProfile'}]}

# %%
d['data'].keys()
# Out:
# dict_keys(['metadata', 'entityUrn', 'elements', 'paging', '$type'])

# %%
d['data']['elements'][1].keys()
# Out:
# dict_keys(['extendedElements', 'elements', 'type', '$type'])

# %%
for data in d['data']['elements'][1]['elements']:
    print(data['memberDistance'])
# Out:
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}

# %%
for index, data in enumerate(d['data']['elements'][1]['elements'],1):
    print(f'\nConnection {index}')
    for key in data:
        print(f'key: {key}')
        print(data[key])
        print('--'*15)
# Out:
# Connection 1
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAtCrwQBnBssAIDRdgzpu367wTZ472uXsk8', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAwOO7oByiG5VfALPzaDc-zZTULxs4P216U', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:666494856
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Sofie Toft Svendsen', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 12 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAACe554gBniS-OmBbzIToVdQ6sdLcKCqAr7I
# ------------------------------
# key: publicIdentifier
# sofie-toft-svendsen-06025b167
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Skadesbehandler hos If Insurance (If P&C Insurance)', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# mTbUpE+aTs60ODLhRQH0cw==
# ------------------------------
#
# Connection 2
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAA5mXbEBzL0x1t8gK8r-LIq7L58tsKRbQsY', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAA7-luUBgXqUvoGxkewe7lB4wNUUfSo8qzo', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:506755071
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Amanda Liv Lerche Hyrdum', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 3 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAAB40d_8BfEZDcFOvC7k0eIVSqxBYrUHm1nI
# ------------------------------
# key: publicIdentifier
# amanda-liv-lerche-hyrdum-053865121
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Bankrådgiver, Trainee hos Jyske Bank', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# k3onKoPIQcS7D6rMW7uJ4Q==
# ------------------------------
#
# Connection 3
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB3XBMBs6aTuvafCmp4ilF2GPb9DHxLdSg', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAG8oVABRClPuA57avz4LzVjCAzBAT4PgzE', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:283391638
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Kevin Willendrup', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 22 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABDkNpYBAqRQb6hp0UupjSoXKtKIIj9pG2A
# ------------------------------
# key: publicIdentifier
# kevin-willendrup-95aaa77a
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Uddannelsesansvarlig hos If P&C Insurance', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# w4Z7AUrQTQ6mUJKAJYQaQQ==
# ------------------------------
#
# Connection 4
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAKrBuEBU0-iNeP6c5lg3Cr9t8NLGoqxmA8', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAALKA9ABwM1kNTrZ2iVD1qiYvKYB1tort9A', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:523712161
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Louise Stecher-Hansen', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 9 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAAB83NqEBfTBU_ZWkzyCZBVEas4K5MnuLV9A
# ------------------------------
# key: publicIdentifier
# louise-stecher-hansen
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': '...', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# GvpuivmwTquPntU0MhW0rQ==
# ------------------------------
#
# Connection 5
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADKNycBfqpQq1j6bCdtRq92h-cID9vCN24', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADx1BMBJTvmXvYDpS2t6woIlH4Rj-2RSpY', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:663565694
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Nikolaj Ancher', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 34 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAACeNNX4BhMHp6Q3gbsWCUGgMZcrLk1ew_K4
# ------------------------------
# key: publicIdentifier
# nikolaj-ancher-b12287166
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Senior konsulent FRIDA forsikring', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# JBK/f7ewT5ef5d0PY1oVDA==
# ------------------------------
#
# Connection 6
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAaYoMAB7wd_B1C8xlYu6CXnjPpw87aNjb0', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABsBTq8B40V2AgUDVofwN7KXlXAn1IVuyqU', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:426432364
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Laura Knudsen', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 4 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABlq12wBkyncuDOQLPqYOAm9orc8VNTu7_U
# ------------------------------
# key: publicIdentifier
# laura-knudsen-ba4989ba
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Junior Underwriter', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# 4l0FVXjsR1iAtYe9oBjJMA==
# ------------------------------
#
# Connection 7
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAACuHQBhodDjj8c25cbcyTbwcG6fFr-BFw', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABHwmwBi5VEdkXs9vznBi6MWuEi-lrCjnI', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB0cBMBt4y8SJDCXGtmdmad3gWuWBkMMVY', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:390773988
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Thomas k. Deloncé', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 37 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABdKvOQBWEfgSDx4Ekgsz05YGAMlU_c4D-E
# ------------------------------
# key: publicIdentifier
# thomas-k-deloncé-430a52aa
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Insurance Consultant at Alka Forsikring', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# uO3HLei7RpGnl48lyTtaZQ==
# ------------------------------
#
# Connection 8
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAAKjeYBY96-3kS7ttenaC-K5iaP41NGz2w', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAB3XBMBs6aTuvafCmp4ilF2GPb9DHxLdSg', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAADAcMEB8HYKxR-GEy8l1DgNsPmxiwPVmUk', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:455388990
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Nikolaj Lehrmann Thygesen', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 11 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABskrz4BwU9YrsqS7Yoy8L_WJ5r6CRH2gIQ
# ------------------------------
# key: publicIdentifier
# nikolaj-lehrmann-thygesen-366613108
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Erhvervsrådgiver hos If P&C Insurance', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# Kb4nebBGQeuNSGqds7UfHg==
# ------------------------------
#
# Connection 9
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABUdCYB74ivapFO4Ljdb5p1fJO0_CRiQM0', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABvG1oBQTJYxGsJWWYeqrDW-sWMJxkqYIM', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:324776978
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Lars Hyldig', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 46 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABNbtBIBqNXMXlqC3UEq9RULq514aAfdnGQ
# ------------------------------
# key: publicIdentifier
# lars-hyldig-78292590
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Development Consultant hos If Insurance (If P&C Insurance)', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# GUqhy4FMSIOLAd15+XgILg==
# ------------------------------
#
# Connection 10
# key: memberDistance
# {'value': 'DISTANCE_2', '$type': 'com.linkedin.voyager.common.MemberDistance'}
# ------------------------------
# key: image
# {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}
# ------------------------------
# key: targetUrn
# urn:li:fs_miniProfile:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos
# ------------------------------
# key: socialProofImagePile
# [{'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAAACLgcBTLNHefMylgfe1EJpAiWKk-3aSt0', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABHwmwBi5VEdkXs9vznBi6MWuEi-lrCjnI', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}, {'attributes': [{'sourceType': 'PROFILE_PICTURE', '*miniProfile': 'urn:li:fs_miniProfile:ACoAAABpopUBh45piRdXx3wfXs3spd4hmQwDv9c', '$type': 'com.linkedin.voyager.common.ImageAttribute'}], 'accessibilityTextAttributes': [], '$type': 'com.linkedin.voyager.common.ImageViewModel'}]
# ------------------------------
# key: trackingUrn
# urn:li:member:280739975
# ------------------------------
# key: title
# {'textDirection': 'FIRST_STRONG', 'text': 'Kate Hedebroe', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: type
# PROFILE
# ------------------------------
# key: $type
# com.linkedin.voyager.search.SearchHitV2
# ------------------------------
# key: headless
# False
# ------------------------------
# key: socialProofText
# 65 shared connections
# ------------------------------
# key: secondaryTitle
# {'textDirection': 'USER_LOCALE', 'text': '2nd', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: *badges
# urn:li:fs_memberBadges:ACoAABC7wIcB_yeZiG5rZab90LdzmKR5MLw8Sos
# ------------------------------
# key: publicIdentifier
# kate-hedebroe-31b0297a
# ------------------------------
# key: headline
# {'textDirection': 'FIRST_STRONG', 'text': 'Uddannelse hos If P&C Insurance', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: nameMatch
# False
# ------------------------------
# key: subline
# {'textDirection': 'FIRST_STRONG', 'text': 'Copenhagen Area, Capital Region, Denmark', '$type': 'com.linkedin.voyager.common.TextViewModel'}
# ------------------------------
# key: trackingId
# YlkzV2dtQyGfuSvQMZvwIw==
# ------------------------------

# %%
linkedin.sign_off(False)
# Out:
# 25-Jul-19 12:05:59 [INFO] Logoff Successful
# [Off] LinkedIn()

# %% [markdown]
# ##### Notes still use pagnination to get everything
#
# current url, check if it is close to the number of shown
